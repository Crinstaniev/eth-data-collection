# %% [markdown]
# # Example Code Using Web3py

# %%
import warnings

from web3 import Web3

warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 import warnings
# ----> 3 from web3 import Web3
#       5 warnings.filterwarnings('ignore')
#
# File ~/.local/share/virtualenvs/eth-data-collection-FAPQ9irR/lib/python3.10/site-packages/web3/__init__.py:6
#       2 import warnings
#       4 import pkg_resources
# ----> 6 from eth_account import (
#       7     Account  # noqa: E402,
#       8 )
#       9 from web3.main import (
#      10     Web3  # noqa: E402,
#      11 )
#      12 from web3.providers.eth_tester import (  # noqa: E402
#      13     EthereumTesterProvider,
#      14 )
#
# File ~/.local/share/virtualenvs/eth-data-collection-FAPQ9irR/lib/python3.10/site-packages/eth_account/__init__.py:1
# ----> 1 from eth_account.account import (
#       2     Account,
#       3 )
#       5 __all__ = ["Account"]
#
# ...
